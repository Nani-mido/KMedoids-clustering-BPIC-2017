# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data1=pd.read_csv('KMedoids clustering results/q_gram sim/no cluster correcting/clusters research1.csv',sep=";")

# %%
data1
# Out:
#    n_clusters    AP    AC    AD
# 0          13  0,98     1  0,94
# 1          14  0,98     1  0,94
# 2          15  0,98     1  0,94
# 3          20  0,99     1  0,98
# 4          40  0,99     1  0,97
# 5          45     1  0,71  0,86
# 6          50     1     1  0,99
# 7          55  0,99  0,99  0,99
# 8          60  0,99  0,99     1
# 9          65  0,99  0,96  0,84

# %%
# data to plot
n_groups = 4
AP = (90, 55, 40, 65)
AC = (85, 62, 54, 20)
AD

# create plot
fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.35
opacity = 0.8

rects1 = plt.bar(index, AP, bar_width,
alpha=opacity,
color='b',
label='AP')

rects2 = plt.bar(index + bar_width, AC, bar_width,
alpha=opacity,
color='g',
label='AC')

rects3 = plt.bar(index + bar_width, AD, bar_width,
alpha=opacity,
color='r',
label='AD')

plt.xlabel('Person')
plt.ylabel('Scores')
plt.title('Scores by person')
plt.xticks(index + bar_width, ('A', 'B', 'C', 'D'))
plt.legend()

plt.tight_layout()
plt.show()

# %%
plt.style.use('ggplot')
data1.plot(kind='bar')
plt.ylabel('AUC per class')
# Out:
# Text(0,0.5,'AUC per class')

# %%
# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
th=dict()
roc_auc = dict()
for i in range(3):
    fpr[i], tpr[i],th[i] = met.roc_curve(actual[actual.columns.values[i+1]],preds[preds.columns.values[i+1]])
    roc_auc[i] = auc(fpr[i], tpr[i])

for i in range(3):
    plt.figure()
    lw = i
    plt.plot(fpr[i], tpr[i], color='darkorange',
             lw=2, label='ROC curve (area = %0.2f)' % roc_auc[i])
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic %r' %actual.columns.values[i+1])
    plt.legend(loc="lower right")
    plt.show()
